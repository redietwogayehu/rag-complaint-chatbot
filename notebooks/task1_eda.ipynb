# %%
import pandas as pd

df = pd.read_csv(
    "../data/raw/complaints.csv"
)

print(df.shape)

df.head()
# Out:
# /var/folders/td/g0nj9lw14y165dmqgtz9jxzh0000gn/T/ipykernel_69257/3421544982.py:3: DtypeWarning: Columns (0: Consumer disputed?) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(
# (2505087, 18)
#   Date received                                            Product  \
# 0    2025-06-20  Credit reporting or other personal consumer re...
# 1    2025-06-20                                    Debt collection
# 2    2025-06-20  Credit reporting or other personal consumer re...
# 3    2025-06-20  Credit reporting or other personal consumer re...
# 4    2025-06-20  Credit reporting or other personal consumer re...
#
#                Sub-product                                 Issue  \
# 0         Credit reporting  Incorrect information on your report
# 1  Telecommunications debt     Attempts to collect debt not owed
# 2         Credit reporting           Improper use of your report
# 3         Credit reporting           Improper use of your report
# 4         Credit reporting  Incorrect information on your report
#
#                                        Sub-issue Consumer complaint narrative  \
# 0            Information belongs to someone else                          NaN
# 1                              Debt is not yours                          NaN
# 2  Reporting company used your report improperly                          NaN
# 3  Reporting company used your report improperly                          NaN
# 4                       Account status incorrect                          NaN
#
#                              Company public response  \
# 0                                                NaN
# 1  Company can't verify or dispute the facts in t...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                         Company State ZIP code Tags  \
# 0           Experian Information Solutions Inc.    FL    32092  NaN
# 1  Eastern Account Systems of Connecticut, Inc.    FL    342XX  NaN
# 2        TRANSUNION INTERMEDIATE HOLDINGS, INC.    AZ    85225  NaN
# 3           Experian Information Solutions Inc.    AZ    85225  NaN
# 4           Experian Information Solutions Inc.    IL    60628  NaN
#
#   Consumer consent provided? Submitted via Date sent to company  \
# 0                        NaN           Web           2025-06-20
# 1                        NaN           Web           2025-06-20
# 2                        NaN           Web           2025-06-20
# 3                        NaN           Web           2025-06-20
# 4                        NaN           Web           2025-06-20
#
#   Company response to consumer Timely response? Consumer disputed?  \
# 0                  In progress              Yes                NaN
# 1      Closed with explanation              Yes                NaN
# 2                  In progress              Yes                NaN
# 3                  In progress              Yes                NaN
# 4                  In progress              Yes                NaN
#
#    Complaint ID
# 0      14195687
# 1      14195688
# 2      14195689
# 3      14195690
# 4      14195692

# %%
df.columns.tolist()
# Out:
# ['Date received',
#  'Product',
#  'Sub-product',
#  'Issue',
#  'Sub-issue',
#  'Consumer complaint narrative',
#  'Company public response',
#  'Company',
#  'State',
#  'ZIP code',
#  'Tags',
#  'Consumer consent provided?',
#  'Submitted via',
#  'Date sent to company',
#  'Company response to consumer',
#  'Timely response?',
#  'Consumer disputed?',
#  'Complaint ID']

# %%
df["Product"].value_counts()
# Out:
# Product
# Credit reporting or other personal consumer reports                             2140547
# Debt collection                                                                  119634
# Money transfer, virtual currency, or money service                                51228
# Credit reporting, credit repair services, or other personal consumer reports      48661
# Credit card                                                                       44843
# Checking or savings account                                                       42961
# Mortgage                                                                          15437
# Student loan                                                                      13280
# Vehicle loan or lease                                                              9250
# Payday loan, title loan, personal loan, or advance loan                            5130
# Credit reporting                                                                   3362
# Prepaid card                                                                       3357
# Credit card or prepaid card                                                        3068
# Debt or credit management                                                          2118
# Bank account or service                                                            1200
# Consumer Loan                                                                       468
# Payday loan, title loan, or personal loan                                           365
# Payday loan                                                                          94
# Money transfers                                                                      74
# Other financial service                                                              10
# Name: count, dtype: int64

# %% [markdown]
# Filter Products

# %%
target_products = [
    "Credit card",
    "Payday loan, title loan, personal loan, or advance loan",
    "Checking or savings account",
    "Money transfer, virtual currency, or money service"
]

filtered_df = df[
    df["Product"].isin(target_products)
].copy()

print(filtered_df.shape)
print(filtered_df["Product"].value_counts())
# Out:
# (144162, 18)
# Product
# Money transfer, virtual currency, or money service         51228
# Credit card                                                44843
# Checking or savings account                                42961
# Payday loan, title loan, personal loan, or advance loan     5130
# Name: count, dtype: int64

# %%
filtered_df = filtered_df[
    filtered_df["Consumer complaint narrative"].notna()
].copy()

print(filtered_df.shape)
# Out:
# (82067, 18)

# %%
filtered_df["Product"].value_counts()
# Out:
# Product
# Money transfer, virtual currency, or money service         38424
# Checking or savings account                                24383
# Credit card                                                16815
# Payday loan, title loan, personal loan, or advance loan     2445
# Name: count, dtype: int64

# %% [markdown]
# Create Product Category Column

# %%
product_mapping = {
    "Credit card": "Credit Card",

    "Payday loan, title loan, personal loan, or advance loan":
        "Personal Loan",

    "Checking or savings account":
        "Savings Account",

    "Money transfer, virtual currency, or money service":
        "Money Transfer"
}

filtered_df["product_category"] = (
    filtered_df["Product"]
    .map(product_mapping)
)

# %%
filtered_df["product_category"].value_counts()
# Out:
# product_category
# Money Transfer     38424
# Savings Account    24383
# Credit Card        16815
# Personal Loan       2445
# Name: count, dtype: int64

# %% [markdown]
# Clean Complaint Narratives

# %%
import re

def clean_text(text):

    text = str(text).lower()

    text = re.sub(r"http\S+", "", text)

    text = re.sub(
        r"[^a-zA-Z0-9\s]",
        " ",
        text
    )

    text = re.sub(
        r"\s+",
        " ",
        text
    )

    return text.strip()

# %%
filtered_df["clean_text"] = (
    filtered_df["Consumer complaint narrative"]
    .apply(clean_text)
)

# %%
filtered_df[
    [
        "Consumer complaint narrative",
        "clean_text"
    ]
].head()
# Out:
#                             Consumer complaint narrative  \
# 12237  A XXXX XXXX card was opened under my name by a...
# 12532  I made the mistake of using my wellsfargo debi...
# 13280  Dear CFPB, I have a secured credit card with c...
# 13506  I have a Citi rewards cards. The credit balanc...
# 13955  b'I am writing to dispute the following charge...
#
#                                               clean_text
# 12237  a xxxx xxxx card was opened under my name by a...
# 12532  i made the mistake of using my wellsfargo debi...
# 13280  dear cfpb i have a secured credit card with ci...
# 13506  i have a citi rewards cards the credit balance...
# 13955  b i am writing to dispute the following charge...

# %%
mkdir -p ../data/processed

# %%
filtered_df.to_csv(
    "../data/processed/filtered_complaints.csv",
    index=False
)

print("Saved successfully")
# Out:
# Saved successfully

# %%
filtered_df.shape
# Out:
# (82067, 20)

# %%
import pandas as pd

df = pd.read_csv("../data/processed/filtered_complaints.csv")

print(df.columns.tolist())
# Out:
# ['Date received', 'Product', 'Sub-product', 'Issue', 'Sub-issue', 'Consumer complaint narrative', 'Company public response', 'Company', 'State', 'ZIP code', 'Tags', 'Consumer consent provided?', 'Submitted via', 'Date sent to company', 'Company response to consumer', 'Timely response?', 'Consumer disputed?', 'Complaint ID', 'product_category', 'clean_text']

# %%
print(df.columns.tolist())
# Out:
# ['Date received', 'Product', 'Sub-product', 'Issue', 'Sub-issue', 'Consumer complaint narrative', 'Company public response', 'Company', 'State', 'ZIP code', 'Tags', 'Consumer consent provided?', 'Submitted via', 'Date sent to company', 'Company response to consumer', 'Timely response?', 'Consumer disputed?', 'Complaint ID']

# %%
df.columns = df.columns.str.strip()

# %%
df["clean_text"] = df["Consumer complaint narrative"].fillna("").astype(str)

# %%
filtered_df = df[
    df["Product"].isin([
        "Credit card",
        "Personal loan",
        "Savings account",
        "Money transfer"
    ])
].copy()

# %%
df = pd.read_csv("../data/processed/filtered_complaints.csv")
df.columns = df.columns.str.strip()

# %%
df["product_category"].value_counts().plot(kind="bar")

import matplotlib.pyplot as plt

plt.title("Filtered Product Category Distribution")
plt.xlabel("Product Category")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
